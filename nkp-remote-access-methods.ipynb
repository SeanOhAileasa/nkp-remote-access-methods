# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-remote-access-methods/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``Remote Access Methods``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# ###### Quick Links
# ***
#
# * [Remote Access Methods](#topremoteAccessMethods)&nbsp;&nbsp;|&nbsp;&nbsp;[Test](#topremoteAccessMethodsTest)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# <a id="topremoteAccessMethods"></a>
# ### [Remote Access Methods](#remoteAccessMethods)
#
# - [1. Virtual Private Network (VPN)](#remoteAccessMethods1VirtualPrivateNetworkVPN) <br/><br/>
# - [2. Remote Desktop Protocol (RDP)](#remoteAccessMethods2RemoteDesktopProtocolRDP) <br/><br/>
# - [3. Secure Shell (SSH)](#remoteAccessMethods3SecureShellSSH) ``Port 22`` <br/><br/>
# - [4. Virtual Network Computing (VNC)](#remoteAccessMethods4VirtualNetworkComputingVNC) <br/><br/>
# - [5. Network Terminal Protocol (Telnet)](#remoteAccessMethods5NetworkTerminalProtocolTelnet) <br/><br/>
# - [6. Hypertext Transfer Protocol Secure (HTTPS)](#remoteAccessMethods6HTTPS) ``Port 443`` <br/><br/>
# - [7. Remote File Access](#remoteAccessMethods7RemoteFileAccess) <br/><br/>
# - [8. Out-of-band Management](#remoteAccessMethods8OutofbandManagement)

# %% [markdown]
# ### [Practice: Configuring Remote Access](#remoteAccessMethodspractice)
#
# * [1. Exercise: Configure Remote Access](#remoteAccessMethodsexercise)

# %% [markdown]
# <a id="topremoteAccessMethodsTest"></a>
# ### ⚡ [Test](#remoteAccessMethodsTest)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="remoteAccessMethods"></a>
# ***
# ### Remote Access Methods
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="remoteAccessMethods1VirtualPrivateNetworkVPN"></a>
# ***
# ######  1. Virtual Private Network (VPN)
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``use a VPN including IPsec, SSL/TLS/DTLS, site-to-site, and client-to-site in a scenario``

# %% [markdown]
# In this presentation, we'll take a closer look at VPNs, or the Virtual Private Network.

# %% [markdown]
# And this is used to provide secure connectivity across an unsecure network domain using encryption.

# %% [markdown]
# And, of course, the unsecure network to which we are referring is the Internet. It is the most public network there is, and as such, it is not secure.

# %% [markdown]
# But the common use cases include accessing a business network remotely. So when you have traveling users or people who work from home, they might need access to the resources of the internal organization. And as such, they need a virtual private network connection.

# %% [markdown]
# And, in fact, it might even go the other way. Maybe the person who works from home is actually in the central site, we'll say. They might then need to access their system at home, so you can go the other direction if necessary. Now that's up to you in terms of how you set this up.

# %% [markdown]
# But, again, the idea is that in terms of connectivity, there is a network that exists between wherever you are when you're traveling and/or wherever you live and your business environment. And that network is the Internet, so let's take advantage of it, let's use it. But, of course, we need to do so in a private manner because it's a public network.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ######  IPsec - Secured Implementation of the IP Protocol
# ***

# %% [markdown]
# [IPsec] So this is where the encryption comes into play.

# %% [markdown]
# Now IPsec, or IP sec, is simply a secured implementation of the IP protocol. And as such, it's ideal for use on the Internet.

# %% [markdown]
# But as mentioned, we need to use the Internet in a private fashion, so we need to encrypt the communications that we are sending back and forth.

# %% [markdown]
# So it's a set of protocols used to secure the communication. And it protects the data that is exchanged between an IPsec gateway and any remote network or any host that supports the IPsec protocol.

# %% [markdown]
# So we see a remote user that is essentially the IPsec client. It negotiates a connection with an IPsec VPN device or a firewall and they, in essence, establish that communication and it creates what's known as a tunnel. And anyone that is able to intercept the traffic, basically only gets encrypted information. So they basically cannot gain access to what the information is. So that's how you use this public network in a private fashion.

# %% [markdown]
# Now, IPsec also allows for isolation with respect to the internal resources. You can create these permitted subnets, so that, essentially, you can say once you have connected to the VPN device or the firewall, you may now access the resources of this permitted subnet. And that allows you to isolate those resources so that you can access them, but perhaps not access other systems that might be a little more secure.

# %% [markdown]
# So that's up to you, however you configure that, but it is supported. So, again, this just handles the encryption so that you can communicate securely.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ######  IPsec - Implements Different Sub-protocols
# ***

# %% [markdown]
# Now, it implements a couple of different sub-protocols, if you will.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ######  IPsec - Sub-protocols - Authentication Header (AH)
# ***

# %% [markdown]
# The Authentication Header, or the AH Component of the packet, handles authentication. So this is always, who are you, prove your identity, that's authentication.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ######  IPsec - Sub-protocols - Encapsulating Security Payload (ESP)
# ***

# %% [markdown]
# And then the encapsulating security payload also works with the authentication of the sender and encrypts the data.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ######  Conclusion - IPsec: i. Sub-protocols; ii. Proprietary
# ***

# %% [markdown]
# So the idea being, authentication, in and of itself, is not particularly useful if you aren't going to encrypt the data. Encrypting the data all by itself is not particularly useful if you aren't going to authenticate who is sending it.

# %% [markdown]
# So the two protocols work in conjunction with each other to provide both services, and now you can be assured of who the information is coming from and that the information itself is protected.

# %% [markdown]
# [SSL/TLS/DTLS] Now one of the issues with IPsec, however, is that it's not really an industry standard protocol. It's somewhat proprietary, it is supported in Windows environments, for example, but not necessarily by everything else. So these are some other protocols that you can use if you need a little more compatibility.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Secure Sockets Layer (SSL)
# ***

# %% [markdown]
# SSL is Secure Sockets Layer, and this is the protocol that you see all the time when you access a secured website.

# %% [markdown]
# HTTPS, in essence, means HTTP secured by SSL.

# %% [markdown]
# So this can be used to establish a link that is encrypted using standard web browsers. Meaning you don't need specific software on the client systems to create the link. You just go to a web page that your environment creates, enter a username and a password, click Connect, and you are connected.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Transport Layer Security (TLS)
# ***

# %% [markdown]
# TLS, or Transport Layer Security, provides data integrity between two communicating applications.

# %% [markdown]
# And this refers to whether or not the packet has been intercepted and/or tampered with. It includes components of the protocol that effectively say, I'm sending this and this is what you should expect to receive. If you receive anything other than this, it indicates the packet has been tampered with, so it should be discarded.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Datagram Transport Layer Security (DTLS)
# ***

# %% [markdown]
# And DTLS, or Datagram Transport Layer Security, is more or less the same.

# %% [markdown]
# But it provides privacy for client/server applications that are typically specific. So this specific application between this client and this server. TLS is a little more generic, if you will.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### VPN Types
# ***

# %% [markdown]
# [Host-to-site VPNs] Now there are different types of VPNs as well, and the first one we'll take a look at is known as the host-to-site.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ######  Host-to-site VPN
# ***

# %% [markdown]
# And this is typically implemented when you have a remote user who needs access to the internal LAN environment.

# %% [markdown]
# So an employee who works from home or travels a fair amount can simply use their own Internet service provider to gain Internet connectivity. Then they typically launch software that is installed on their devices to establish the connection into the LAN environment.

# %% [markdown]
# Now that software can be third-party or, in most cases, it can be part of the operating system. Most Windows clients, for example, have the ability to create a VPN, inherently, within the operating system. But it's typically casual access, if you will. They don't need connectivity all the time. They can do most of their work disconnected. But then when they need to get to a file, or a printer, or a mail server, or an intranet site, they make the connection, they do what they need to do, and then they close the connection down.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ######  Host-to-host VPN
# ***

# %% [markdown]
# So, again, it's more casual, if you will. Now you might also see a host-to-host, which is fairly similar, but it is directly connecting two systems.

# %% [markdown]
# They still have to authenticate prior to data transmission to ensure the authenticity, the integrity, and the confidentiality of the data. But it's not so much a single user accessing multiple resources within the LAN, it's a single system directly to another single system. Those aren't as common, but certainly still possible.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ######  Site-to-site VPN
# ***

# %% [markdown]
# [Site-to-site VPNs] And then we have the site-to-site VPN.

# %% [markdown]
# This tunnels data between local area networks using the Internet. And generally requires a concentrator or a dedicated hardware device at each site.

# %% [markdown]
# So the VPN is, effectively, set up between the two devices.

# %% [markdown]
# Once that is done, then all users in one location can access the resources in the other location and vice versa. So it's a little more persistent, in fact, it might be connected all the time. But it's not a specific user launching software to create a connection to the LAN environment. It's this continually available connection, so that users on either side can access the resources of the other side.

# %% [markdown]
# Now with this type, you might also see an intranet based versus an extranet based. And this just depends on whether or not you do business with some kind of other organization.

# %% [markdown]
# So the intranet based, in essence, means it's set up all within your organization.

# %% [markdown]
# And extranet means it's set up with a business partner.

# %% [markdown]
#  So that's your call, but it's the same structure. It's still the VPN connectivity, in essence, configured between the hardware devices as opposed to an individual user launching software to make the connection. Because if you tried to do that in an environment where it really called for a site-to-site, you'd have tons of users all launching these connections to establish connectivity. And it would just become far too difficult to manage. So by setting it up between the two hardware devices, it's established it's ready to go, and then everyone can use it.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="remoteAccessMethods2RemoteDesktopProtocolRDP"></a>
# ***
# ######  2. Remote Desktop Protocol (RDP)
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``use RDP in a scenario``

# %% [markdown]
# Now in this next section, we'll take a look at several protocols used to establish remote connectivity to other systems. And we'll begin with RDP, or the Remote Desktop Protocol.

# %% [markdown]
# And this is actually a proprietary protocol developed by Microsoft.

# %% [markdown]
# And it provides users with the ability to access a remote computer's desktop over any network connection, including the Internet. Now that requires a little additional configuration, but it can still be done.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# And, again, the idea is that you don't just establish a connection to access a shared file or a shared printer or something along those lines, you quite literally see the desktop of the remote computer. So this is something that many network administrators live by. They need to administer many servers that could be quite geographically separated. So as long as you have network connectivity to those servers, you can simply access the remote desktop and perform, virtually, any task. At least from a software perspective, there is nothing you can't do. You might as well be sitting at that computer.

# %% [markdown]
# Now this is actually something that evolved from an earlier Microsoft service known as Terminal Services. And even that, essentially, evolved from some of the oldest methods of connecting to remote systems way back in the days of mainframes.

# %% [markdown]
# Effectively, the mainframe did everything. It did all the processing, all the storage was accessed from the mainframe. But you had terminals that were connected to the mainframe so that you could at least interact with them. So you might have a keyboard and a screen in front of you, but you are remotely connecting to the mainframe to give it the instructions and tell it what to do.

# %% [markdown]
# So, in other words, the terminal really did nothing. It might have looked like what we tend to think of as a computer. But they were actually referred to as dumb terminals because they didn't do anything but provide an interface.

# %% [markdown]
# So Terminal Services was essentially the same thing, connecting to a remote computer. All the processing, all the work, is being done on the remote system.

# %% [markdown]
# You aren't really doing anything except accessing an interface, and that, again, carries through to the Remote Desktop Protocol.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Remote Desktop Client Utility
# ***

# %% [markdown]
# You have a small piece of software on your client, the Remote Desktop client utility.

# %% [markdown]
# That is simply used to establish and maintain the connection. But once you are connected to that remote desktop, everything you do happens on the remote system.

# %% [markdown]
# So your system becomes little more than a terminal.

# %% [markdown]
# But, of course, you can run other applications along with the RDP connection. So your system, of course, is no longer a dumb terminal.

# %% [markdown]
# But once you make the connection to that remote system, whatever it is that you do happens on the remote system.

# %% [markdown]
# So this provides secure network communications, as well. And, as mentioned, it's ideal for remote management.

# %% [markdown]
# So that you can remotely diagnose and resolve problems, whether they be with servers or maybe it's for the benefit of telecommuters who are working from home or maybe from a branch office. But, again, the idea is to simply be able to access that system in its entirety to do whatever it is you need to do on that remote system without having to actually go anywhere.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Features
# ***

# %% [markdown]
# It offers several features, such as encryption, to ensure that the data being transferred is secure.

# %% [markdown]
# It supports smart card authentication, if you are using that.

# %% [markdown]
# It supports compression for bandwidth reduction, resource sharing so that the remote system can actually make use of the resources that you have on your own local system. For example, if I connect to the remote system and open a document and I want to print that document, I can print it on my local printer that is attached to my own local system. So that's resource sharing.

# %% [markdown]
# Multiple displays are supported. And you can even disconnect without logging off. So that if you are going to reconnect, let's say, in a short amount of time, it can maintain your session if desired.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Protocol Distinction - Remote Desktop Connection (RDC) versus Remote Assistance
# ***

# %% [markdown]
# Now, one other distinction with respect to the protocol is, really, just how it's used.

# %% [markdown]
# Officially, there are two applications in Windows environments.

# %% [markdown]
# Remote Desktop Connection

# %% [markdown]
# The Remote Desktop Connection, which, again, just allows you to log on to a Windows computer remotely and access its entire desktop.

# %% [markdown]
# But then there is also Remote Assistance, and this incorporates components of RDP, if you will, but its purpose is a little different. It allows you to connect to an existing Windows session to effectively provide, as the name indicates, assistance, technical support.

# %% [markdown]
# So, typically, the way that you distinguish the two is that when you use a Remote Desktop Connection, it's usually into a server, it doesn't have to be. But it's usually an administrator remotely accessing a server to perform administrative tasks. And as such, there usually is no one else using that server. There's nobody sitting at the console doing anything. And, in fact, that is the case with most servers. You generally don't use them in a day-to-day fashion.

# %% [markdown]
# But Remote Assistance is someone who is actually sitting at the computer and needs help. So you can establish a Remote Assistance connection. You can see the desktop and you can even take control if necessary, but it's basically to walk a person through a problem. If they don't know how to access a certain feature or perform a certain task, you can tell them, launch this application, click here, enter that. In essence, instruct them or walk them through the process so that they can complete the task.

# %% [markdown]
# But, again, the idea is that they are there performing the task, they are still logged in as themselves. You can just see that as it's happening. And as mentioned, if necessary you can take control, but you don't really log in to the system. That person is logged in as themselves.

# %% [markdown]
# And when you establish a Remote Desktop Connection, you log in as yourself. So that's another difference as well, the identity of the user.

# %% [markdown]
# Now, both of these features can be enabled or disabled at the discretion of administration, so you do not have to have them on.

# %% [markdown]
# Servers tend to have them enabled by default. And, usually, the Professional Editions or the Business Editions of the desktops in Windows support it, but it might not be enabled.

# %% [markdown]
# But one of the differences is that servers support multiple connections by default, clients only support one.

# %% [markdown]
# But Remote Assistance is usually disabled by default on all systems so you do have to enable it.

# %% [markdown]
# Now you can do both through something like a group policy, wherein you can distribute the settings with a policy that basically says, these systems all have it off or those systems all have it on, for either feature. But that, again, is up to you.

# %% [markdown]
# But, ultimately, Remote Desktop Connectivity is a very necessary feature in most environments these days to simply be able to establish connections to remote systems from any location.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="remoteAccessMethods3SecureShellSSH"></a>
# ***
# ######  3. Secure Shell (SSH) - ``Port 22``
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``use SSH in a scenario``

# %% [markdown]
# In this presentation, we'll take a look at our next remote connectivity protocol, SSH, or Secure Shell.

# %% [markdown]
# And very much like the Remote Desktop Protocol that we just saw, this provides a secure way to access a computer system remotely.

# %% [markdown]
# It establishes authenticated and secure encrypted data communications.

# %% [markdown]
# And it's commonly used by administrators for managing servers and the applications on those servers remotely.

# %% [markdown]
# It allows you to log in to those systems. You can then perform maintenance, troubleshoot various issues, and of course, execute commands.

# %% [markdown]
# So, again, very similar to the Remote Desktop Protocol. But this uses a standard client/server model, wherein you have a client application that is used to establish a connection into an SSH server. Now, regardless of the official classification of client versus server, the client is simply whichever system you used to initiate the session and the server is any system that accepts the incoming requests.

# %% [markdown]
# So you do not necessarily have to be designated as a server type of operating system. It's any system that is accepting the connection.

# %% [markdown]
# Now that is essentially the same in the Remote Desktop Protocol, as well, because even if you have two desktop systems, say, running Windows 10, you can connect from one to the other. So the client is whichever one you used to initiate the connection, and the server is whichever one accepts that request. So, again, client/server in terms of the classification of the operating system is a little bit skewed.

# %% [markdown]
# But as for SSH itself, it uses port 22 by default to communicate, but you can change that if you want to. And it is available in most operating systems by default, but primarily Unix and Linux. And this is where you find the most significant difference between SSH and something like Remote Desktop Protocol.

# %% [markdown]
# Recall that RDP is a Microsoft proprietary protocol, hence, that's the reason you don't normally see it installed on Windows. Now it is available for Windows, but it's not there by default, RDP is. So you can certainly download SSH-based applications for Windows, if you are familiar with an application known as PuTTY, that is a very common SSH-based utility that can be installed on Windows.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Protocol based on Three main Utilities - ``Slogin`` - ``SSH`` - ``SCP``
# ***

# %% [markdown]
# Now the protocol itself is based on three main utilities, Slogin, SSH, and SCP.

# %% [markdown]
# And, of course, SSH does represent the shell component, but Slogin is, of course, to handle authentication. This secure shell aspect is to present you with the desktop environment. And SCP is Secure Copy Protocol, so that you can implement copy operations.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Protection
# ***

# %% [markdown]
# And in terms of protection, it can assist in protecting the network from IP spoofing, IP source routing, and DNS spoofing.

# %% [markdown]
# It's a quite stable protocol, it's been around for a long time.

# %% [markdown]
# It has gone through a few different versions, of course, like almost anything, but the later versions are very stable, very secure and quite resistant to those types of attacks. So it is certainly a secure implementation of remote connectivity.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="remoteAccessMethods4VirtualNetworkComputingVNC"></a>
# ***
# ######  4. Virtual Network Computing (VNC)
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``use VNC in a scenario``

# %% [markdown]
# The next remote connectivity protocol that we'll see in this presentation is VNC, or virtual network computing.

# %% [markdown]
# And again, this is a technology for remote desktop sharing.

# %% [markdown]
# And you might see it commonly used to remotely access a home computer. Certainly while traveling or even while in the same LAN, that's perfectly fine.

# %% [markdown]
# And it offers a lot of the same functionality as RDP and/or SSH. But one of the primary differences is that this is an open source application. And it's not included by default with any operating system that I'm aware of. But it can be installed on just about any operating system, but it's just not there by default.

# %% [markdown]
# So you can see that there is a VNC server component and then VNC client components. And you simply establish the connection from the client into the server. And essentially that supports the session.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Network Administration
# ***

# %% [markdown]
# Now, in terms of network administration, it is still commonly used by administrators to remotely administer servers or desktops.

# %% [markdown]
# You can then perform maintenance, troubleshoot, update, do all of the same tasks that you might be able to do using RDP or SSH.

# %% [markdown]
# But again, not only is it not there by default, but I typically find that its use is a little different. You certainly can use it for administration exactly as indicated here. But you can see by the graphic, the VNC viewer software on the clients. Meaning that what you can do is to configure the clients to only view what is happening on the server as opposed to interacting with the desktop.

# %% [markdown]
# So a common implementation of the VNC is if I'm at the server and I need to present some kind of slideshow or maybe show you how to perform a particular task, a demonstration of some kind. And I want multiple people to be able to see that from just about any location, whether it's within the LAN or even over the Internet. They can all see what I'm doing. So it's a very effective training tool. Rather than having to email a presentation to all of these people and have them go through it on their own. They can, for lack of a better word, tune in to my session on the server, and they can see everything that I'm doing.

# %% [markdown]
# So it's very good for those types of applications as well, and that's why you see the VNC viewer software. But it can be configured so that they can interact as well.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Support
# ***

# %% [markdown]
# In terms of support, you can run VNC on Windows, various Mac OS's, and of course, Linux and the various derivatives of Linux.

# %% [markdown]
# But it is essentially and alternative. So you can certainly do a lot of these same things with Remote Desktop or even Apple Remote Desktop (``ARD``).

# %% [markdown]
# But it really does depend on what you are trying to do. If it is something like administration and you are already in a Windows environment, well then you have RDP by default. But RDP is limited to a degree, in terms of the number of connections. In fact, even on servers, RDP by default only supports two simultaneous connections. So if you need more than that, you actually have to purchase licenses to allow for more. Now again, that's simultaneous, so two at the same time can be into a server. If you need three or more, you must purchase more licenses.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# But if you are trying to do something like the presentations that I talked about, the demonstrations, the training. Then VNC is probably a better product, because you can have multiple people tuning into your session. Whereas Remote Desktop just does not support any more than two simultaneous. Plus those sessions are kept separate from each other. So if I remote into a server and you remote into a server using RDP, I don't really see what you're doing and you don't see what I'm doing. So again, it depends on what it is you want to actually do. But it is available, as mentioned, usually for free because it is open source. So if you feel that you have some kind of task that is better suited to VNC, it's no problem to install it. It's very widely supported. But if it's something like just administration, well, in a lot of cases, Windows Remote Desktop is already there and already available.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="remoteAccessMethods5NetworkTerminalProtocolTelnet"></a>
# ***
# ######  5. Network Terminal Protocol (Telnet)
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``use telnet in a scenario``

# %% [markdown]
# Our next remote connectivity protocol is Telnet, and this is a network terminal emulation protocol.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The name doesn't really stand for anything, it really is just a name. But the TE does tend to indicate that terminal emulation.

# %% [markdown]
# But this is a user command for accessing computers remotely. So again, administrators can access someone else's computer remotely to perform troubleshooting or various tasks.

# %% [markdown]
# And the commands that you enter into the Telnet program are certainly entered on your own computer. But they are executed on the remote computer as if you're on the remote system's console.

# %% [markdown]
# So again, this hearkens back to those early days that I mentioned in a previous presentation about mainframes. Everything is actually executed on the mainframe. The terminal was simply the means by which you could interface with it. So no matter what you typed in on your screen, nothing happened on your system. It was simply sent back to the mainframe and executed there. So that's the idea of terminal emulation. I am entering the command on my own system but it gets sent to the remote system and executes there. So it allows the remote system to be controlled and to even communicate with other systems on a network if desired.

# %% [markdown]
# So again, this does sound a awful lot like RDP. But one of the core differences is that Telnet is entirely command driven. There is no graphic interface at all with Telnet. It's a very old protocol, it has been around for a long time. So no graphic component whatsoever with Telnet.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Sessions
# ***

# %% [markdown]
# Now, the session still requires a valid username and password of the remote system.

# %% [markdown]
# So whatever system I'm trying to connect into, I need a valid set of credentials that exist on that system, not my own system.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Privileges
# ***

# %% [markdown]
# In terms of the privileges, you log on as a regular user, again, of that system.

# %% [markdown]
# So your privileges are assigned based on what was granted by the particular application or the data on that computer.

# %% [markdown]
# So again, it comes down to which set of credentials you supply. It doesn't mean that it can't be an administrative account. But it must be an account that exists on that computer, and the privileges are dependent on what have been granted.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Bi-directional Communication - Other Protocols
# ***

# %% [markdown]
# So overall, the Telnet protocol, again, was designed to provide this bi-directional communication.

# %% [markdown]
# But as I mentioned, it's very old. It is only command line driven. So it doesn't need to be particularly robust in terms of its communication capabilities. It operates on a simple 8-bit or byte per transmission protocol, but you’re only typing in plain text commands. So it does not need a lot of bandwidth.

# %% [markdown]
# But it does allow for a standard method of interfacing with any kind of terminal device and executing the necessary processes. And what that comes down to is it’s not only used for interfacing with other computers, but a lot of internetworking devices support Telnet as well. It's very common, or at least it was very common back in the earlier days of routing, to use Telnet to connect to a router to configure it.

# %% [markdown]
# Because again a router does not have any kind of graphic interface. You just connect to it, you establish the session and you enter in the commands on your computer. But they are executed on the router, and that's how you configured it. So it's still in use but not as common anymore.

# %% [markdown]
# Other protocols are capable of doing the same thing and even presenting it with graphic interfaces now. But certainly still available, and it's a very simple protocol, very easy to initiate, very low overhead. So it tends to operate fairly quickly, and it's not particularly complex either. But you do need to know the command syntax for whichever system you are connecting into to be able to operate over Telnet.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="remoteAccessMethods6HTTPS"></a>
# ***
# ###### 6. Hypertext Transfer Protocol Secure (HTTPS) - ``Port 443``
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``use an HTTPS management URL in a scenario``

# %% [markdown]
# In this presentation, we'll take a look at the secure version of Hypertext Transfer Protocol, or HTTPS.

# %% [markdown]
# And this, of course, is used to send secure data between a browser and a web site.

# %% [markdown]
# We're all very familiar with HTTP, if you go to any web site that does not exchange any information, then HTTP itself is fine.

# %% [markdown]
# But as soon as you need to exchange information between your end and the web server, then you typically want that to be secured. And that's where HTTPS comes into play.

# %% [markdown]
# It uses port 443 by default, and also works in conjunction with what's known as an SSL certificate.

# %% [markdown]
# That's Secure Sockets Layer, and we'll talk about the certificate in a moment.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Practical Applications
# ***

# %% [markdown]
# So in terms of practical applications, again, this is used to protect highly confidential online transactions such as online banking, online shopping, or webmail.

# %% [markdown]
# This, of course, is information that you want to ensure is protected as you send it over the very public Internet. And that is exactly what HTTPS does.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Benefits - Secure Sensitive Information
# ***

# %% [markdown]
# So in terms of benefits, it secures that sensitive information, such as credit cards, bank cards.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Benefits - Authenticity - Secure Sockets Layer (SSL)
# ***

# %% [markdown]
# And coming back to the SSL certificate, it also provides authenticity.

# %% [markdown]
# Meaning that customers can verify if the business is legitimate.

# %% [markdown]
# If I want to start a bank, for example, and I want to support secured transactions, I need to apply for a certificate.

# %% [markdown]
# I get investigated by third-party companies that will ensure that I am who I claim to be and that I'm offering the service I claim to offer.

# %% [markdown]
# In essence, that I am legitimate. And as long as I pass, I get a certificate, and that goes on my site, if you will. So that when people access the site, they see the certificate, and they know that it is the legitimate site.

# %% [markdown]
# And a lot of attackers and phishing scams will create fake sites that look exactly like the real sites. But there would not be a certificate, or at least not a valid publicly trusted certificate, and the URL wouldn't match either. So if you look at the address, the scamming sites basically don't have an address that looks anything like the actual bank's site, for example.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Benefits - Trust
# ***

# %% [markdown]
# So this imparts trust, customers are more likely to make transactions on secure sites using HTTPS.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Protocols for Encryption
# ***

# %% [markdown]
# Now the secure component is, of course, the data that's being transferred back and forth. And this is protected by using encryption.

# %% [markdown]
# HTTPS generally uses two secure protocols for encryption, Secure Sockets Layer and TLS.

# %% [markdown]
# > i. Secure Sockets Layer (SSL)
#
#
# > ii. Transport Layer Security (TLS)

# %% [markdown]
# And both protocols are known as an asymmetric Public Key Infrastructure, or PKI system. And we'll take a look at that in a moment.

# %% [markdown]
# But the asymmetric aspect means that it uses two different keys. Despite the fact that it's called public key infrastructure, there's actually a public and a private. And as mentioned, we'll see that in a moment. But it's the idea that there are different keys in use to protect the overall communication.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ######  Public Key Infrastructure - One-way Communication
# ***

# %% [markdown]
# [PKI – One way] So with respect to that implementation, PKI can be implemented in either one-way communication or two-way.

# %% [markdown]
# But when it's a one-way communication, it is still this asymmetric system where it uses two keys to encrypt the overall communication. The public key is used to encrypt the data. And the private key is the only thing that can be used to then decrypt the information that was encrypted with the public.

# %% [markdown]
# Now, the keys themselves are based on exceptionally large prime numbers, and I mean exceptionally large, hundreds of digits.

# %% [markdown]
# And the reason for this is that if you take two exceptionally large prime numbers, you get an exceptionally, exceptionally large semi-prime as an answer. And it just simply means that the answer was created by these two prime numbers, that's a semi-prime.

# %% [markdown]
# And semi-primes have the unique characteristic that the only way to figure out which two original numbers were used to create this number is to try every possible number.

# %% [markdown]
# There's no algorithm that you can run them through that says, this number x and this number y were the two factors that were used. You have to try every single possible number to get at the answer, that’s the essence of PKI. The only way to crack the decryption is to, in short, try every possible combination.

# %% [markdown]
# And the numbers of combinations are so high that it’s just practically impossible. It would take thousands of years for a very high powered computer to run through every possible combination, so it's just not practical.

# %% [markdown]
# So anyway, with the one-way traffic, the sender, before sending a plain text message, requests the public key of the recipient. So if I'm the sender and you are the recipient, I request your public key. Anyone can get a public key, but that is the means to encrypt the data. The private key is held only by you, and it essentially knows what it sent you as the public key.

# %% [markdown]
# But again, anything that is encrypted with the public can only be decrypted with the private. And since you are the only one who holds the private, you are the only entity that is able to decrypt it. So you encrypt it with the public, you send it on its way. If someone were to intercept that, the only thing they can get is a public. The public key cannot be used to decrypt data that was encrypted with a public key. You then use your private key to access the data and reverse the encryption. And you are presented with the original plain text. But that's only useful in a one-way transaction.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ######  Public Key Infrastructure - Two-way Communication
# ***

# %% [markdown]
# [PKI – Two way] If it's two-way, and we both need to talk to each other, then we, in fact, need a third key.

# %% [markdown]
# So the process is still the same, if I'm sending you information or if I need to send you anything, I still request your public key.

# %% [markdown]
# But I don't protect the original message with the public key, I generate a third key known as a symmetric key.

# %% [markdown]
# This is another encryption algorithm. And I protect that algorithm with the public key.

# %% [markdown]
# If we are going to communicate two ways in an encrypted manner, we both need to use the same key. We both need to speak the same language, if you will. So I generate a new key, I protect it with your public, and I send it off to you. You still have the private, which is the only thing that can be used to decrypt anything that is encrypted with the public. And what I see is the symmetric key.

# %% [markdown]
# Now I know what you are using to protect your information.

# %% [markdown]
# When I need to respond back to you, I use the same symmetric key. And since you generated it in the first place, you know what it is, I know what it is, we both know what it is.

# %% [markdown]
# But again, from the perspective of an attacker, if they were to intercept it, they can get a public key. But a public key is useless in decrypting anything that was encrypted with a public key. So the symmetric key remains protected.

# %% [markdown]
# So in terms of Internet banking, the bank would be the recipient, you would be the sender. The bank is the only entity that maintains the private key. Therefore, they are the only ones able to access the symmetric key that you just sent them, and that secures the two-way communications.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - HTTPS is Secure
# ***

# %% [markdown]
# So if you are still hesitant to use HTTPS as a way to secure your Internet communications, it is a very safe and effective method for communicating securely on the Internet. And again, it is far safer than handing your credit card to someone in a restaurant or in a hotel. They now have your credit card number. But passing it over the Internet in this fashion is very, very secure.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="remoteAccessMethods7RemoteFileAccess"></a>
# ***
# ######  7. Remote File Access
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``use remote file access such as FTP/FTPS, SFTP, and TFTP``

# %% [markdown]
# Now, in this presentation, we'll take a look at remote file access. Which is not really a protocol per se, but rather just a very generic service.

# %% [markdown]
# And it allows files to be accessed from virtually any location at any time of the day using any type of device. Including a desktop, a laptop, or a mobile such as a tablet or a phone.

# %% [markdown]
# So again, it's just a very generic term that, in essence, says you are able to access files from anywhere.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Corporate Implementation
# ***

# %% [markdown]
# So in terms of corporate implementations, this can allow access to a corporation's network.

# %% [markdown]
# The employees at a branch office, for example, might need access to the files in headquarters or vice versa. You might have telecommuters who work from home. And you might have employees who, of course, travel very frequently, all of whom need access to these documents. And you can kind of reverse the direction, as well. If, for example, you are traveling and you need access to your home environment, you can certainly access those documents from the road or anywhere else.

# %% [markdown]
# Really, as you long as you have Internet connectivity or, of course, LAN connectivity, you can access these files.

# %% [markdown]
# Now, you can implement it over dedicated lines between computers and a main corporate local area network if that is appropriate. This certainly has the benefits of being secure and very high speed. But in terms of disadvantages, it's more expensive and a little less flexible. But it always comes down to what you feel is better suited to your needs.

# %% [markdown]
# But the dedicated line typically would mean that you are simply accessing the files within a LAN environment. You aren't really doing it over the Internet.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Remote Access Server
# ***

# %% [markdown]
# But you can certainly implement a remote access server if desired.

# %% [markdown]
# Which is a computer with the associated software that is configured to handle multiple users seeking access.

# %% [markdown]
# Now this often includes a firewall to ensure security. But this facilitates the ability to access those files from just about anywhere, so over the Internet, of course.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ######  File Transfer Protocol (FTP) - File Transfer Protocol Secure (FTPS) - Transport via TCP
# ***

# %% [markdown]
# [FTP/FTPS] Now FTP, or the File Transfer Protocol, and its secured version, FTPS, are just very common examples of a remote file access implementation.

# %% [markdown]
# This is a protocol used for exchanging files over the internet and offers the standard client server architecture.

# %% [markdown]
# Wherein you typically have a dedicated server that accepts the incoming request. And then any number of clients that can connect to the server.

# %% [markdown]
# And the data transfer is enabled and facilitated using standard TCP/IP protocols.

# %% [markdown]
# So the local host will connect to the remote host, usually by its IP address or maybe by a DNS name.

# %% [markdown]
# And typically you have to authenticate, you supply a user name and a password. Although I will tell you that FTP does support anonymous connections.

# %% [markdown]
# So you can install just about any kind of FTP software on the client or local host. And they typically allow the files to be viewed, and you can often drag and drop them to make it nice and easy. Once you establish the connection to the server, you typically see the folder structure that is available. And you can just drag the files from your local system into the appropriate folder on the server.

# %% [markdown]
# And a very common implementation of this is for websites. The developers of the websites typically are not in the same place as the servers. A lot of web servers are in cloud type of environments. So as they develop the pages locally, they upload them to the web server and maintain the websites that way. But that's only one example.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ######  Secure File Transfer Protocol (SFTP)
# ***

# %% [markdown]
# [SFTP] Now, the secure file transfer protocol is really, of course, just the same thing, but it provides securer file transfer capabilities.

# %% [markdown]
# So this uses the same kind of key exchange that we just talked about in our last presentation to secure the file access, file transfer, and the file management.

# %% [markdown]
# So we still see a client and server, but they establish this encrypted tunnel between them by using the standard PKI key exchange mechanism.

# %% [markdown]
# This way, all information that is transferred is done so securely.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ######  Trivial File Transfer Protocol (TFTP) - Transport via UDP
# ***

# %% [markdown]
# [TFTP] Now, there's also a down level version of this protocol, if you will, known as Trivial File Transfer Protocol, or TFTP.

# %% [markdown]
# And this is still a technology for transferring files between devices on a network, but it's just a simplified version of FTP.

# %% [markdown]
# You might see it a little more commonly when you aren't concerned with authentication, but it still offers that client server architecture.

# %% [markdown]
# But the core difference really is the transport protocol.

# %% [markdown]
# UDP is used as the transport protocol as opposed to TCP, so regular FTP uses TCP as its transport.

# %% [markdown]
# TFTP uses UDP, and recall that UDP does not use acknowledgements.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ######  Conclusion - Communication Reliability
# ***

# %% [markdown]
# So again, it's frequently used when you just aren't as concerned with the reliability of the communication.

# %% [markdown]
# So it can be used for both uploading or downloading, it doesn't matter. But typically preferred when speed is better than reliability. And again, that's the overall essence of TCP versus UDP.

# %% [markdown]
# TCP is reliable but slow, UDP not as reliable but fast. So again, it really comes down, to the application you are using and which aspect of the protocol you feel is more beneficial.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="remoteAccessMethods8OutofbandManagement"></a>
# ***
# ######  8. Out-of-band Management
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``use out-of-band management such as a modem or console router``

# %% [markdown]
# Now in this presentation, we'll take a look at our final topic out of the category of remote connectivity.

# %% [markdown]
# And this doesn't really refer to remote connections or even a specific protocol or a specific device.

# %% [markdown]
# It's a fairly generalized approach really known as out-of-band management.

# %% [markdown]
# Now for all intents and purposes, the way by which you work in your environment on a day-to-day basis using your standard computers. Your standard IP networks, your standard devices, is referred to as in-band management. In other words, it's the normal way by which you perform your day-to-day tasks.

# %% [markdown]
# So out-of-band management quite loosely means any other way to do the same thing outside the norm.

# %% [markdown]
# So it involves implementing separate dedicated channels or networks used to access the networking equipment. And it can be used to manage the network if one or more of the devices or services should fail. So it effectively means that there's redundancy in place.

# %% [markdown]
# There's alternate methods to perform those same day-to-day tasks other than what's normal. That's the out of band management.

# %% [markdown]
# Now as mentioned, this typically implements some redundancy features. So it requires dedicated communication channels. It also requires dedicated devices and power. Anything that is part of the out-of-band management approach should not be affected by any kind of network failure.

# %% [markdown]
# So you have to try to decide for yourself what's necessary, what's most important. Then you have to implement some kind of out-of-band management approach. So that these prioritized devices or services can still be managed throughout a failure.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ######  Console Server
# ***

# %% [markdown]
# Now the console server is something that you can implement to provide simple and reliable access to other devices.

# %% [markdown]
# So it's centralized access to any connected device.

# %% [markdown]
# In this example, the router, the switch, and the firewall are all connected to the console server.

# %% [markdown]
# So that means I can access any one of those devices and its console through the console server.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Coming back to the normal approach, I would generally just use my computer and establish a connection over the standard IP network to the console server.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# That then allows me to access those devices, and that's the in-band approach.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# But let's say the IP network just went down. Some kind of failure or something, whether it's power or devices taking down that IP network.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Well, you can implement a dial up connection using a modem over the public switched telephone network to dial in to that console server.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# And as long as the console server itself and the devices on the other end are up and running. You can continue to manage those devices on the other end that are still up and running.

# %% [markdown]
# And you can continue to manage those devices using that modem-based connection.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# So that represents your out-of-band management.

# %% [markdown]
# So again, typically, you access the console using a secure and dedicated IP address. That's the normal approach. But if that's not an option, the network has failed, we can revert to this alternate method. So that's the out-of-band approach.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Considerations
# ***

# %% [markdown]
# Now in terms of considerations, you do need to think about the visibility with respect to, do you need access to GUI-based operating systems.

# %% [markdown]
# Or can you access everything you need using a command line interface? If you are only using the command line interface, are you also able to access any peripherals to the command line interface.

# %% [markdown]
# Such as SANS, drive, network interface cards, anything else to which you need access?

# %% [markdown]
# You should also think about how much data is going to be transferred. In other words, do you need to perform fairly robust updates or patching? Do you need to update code? What are the security considerations for the devices attached? Things along those lines.

# %% [markdown]
# So this can all help to determine the costs and the administration requirements for implementing the out-of-band configuration.

# %% [markdown]
# So again, you try and identify what the priorities are. What still needs to be accessible? How can we access them if this fails? And how extensive do the operations need to be with respect to whatever it is you're going to perform? So certainly, it will involve some additional cost, some additional overhead, but you gain reliability. So it's always a matter of trying to determine what's most important and what are the methods you can implement to mitigate some of those possible problems when a failure occurs.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="remoteAccessMethodspractice"></a>
# ***
# ### Practice: Configure Remote Access
# ***

# %% [markdown]
# i. Describe the difference between a host-to-site and a site-to-site VPN.
#
#
# ii. Then to describe a scenario for when to use VNC.
#
#
# iii. Then to describe the benefits of using HTTPS.
#
#
# iv. And finally, to describe the benefits of using out-of-band management.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="remoteAccessMethodsexercise"></a>
# ***
# ###### 1. Exercise: Configure Remote Access
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``configure remote access methods in a given scenario``

# %% [markdown]
# i. All right, so to review, our first task was to describe the difference between a host-to-site and a site-to-site VPN.

# %% [markdown]
# - And the host-to-site is typically a single, or maybe a few clients that use software to initiate a connection to a remote LAN for, if you will, casual resource access. In other words, they don't need to be connected all day, every day. They can work from home or from a hotel when travelling. And when they need access to the resources, they can establish the connection, do what they need to do and then just simply shut it down.

# %% [markdown]
# - But a site-to-site is a more persistent connection configured between dedicated VPN concentrators at each site. So multiple users can all access resources at each site. So no user has to launch a connection. The connection is already there, and it's typically much more bi-directional. Users on either end can access the resources on the other end. So it really just comes down to what you need in terms of resource access, how many people, and how often are they connected.

# %% [markdown]
# ii. Then we asked to describe a scenario for when to use VNC.

# %% [markdown]
# And there are a few, but typically you might see this when sharing a presentation or demonstration among multiple users. All the people who connect into the VNC server can see what is going on on the screen of the server so it's very good for training type purposes. But you might also see it when just connecting to a server for remote administration purposes. And that is very much like the remote desktop protocol or secure shell protocol that we discussed. But VNC might be a little more flexible in terms of the operating systems that it can be installed on and the number of connections that are supported.

# %% [markdown]
# iii. Then we asked to describe the benefits of using HTTPS.

# %% [markdown]
# And the primary benefit is the ability to transfer data and private information securely over the public Internet. The Internet in its default state is, of course, not secure at all. So the HTTPS protocol provides a way to establish these connections and to ensure that they are secured against attack or intrusion.

# %% [markdown]
# iv. And finally, we asked to describe the benefits of using out-of-band management.

# %% [markdown]
# And this quite simply provides the ability to continue to manage a network environment during a failure of one or more devices or services. So again, it implements redundancy, alternate methods to do what you normally do, using some kind of different approach. And that refers to the out-of-band. The way that you do things normally, day in and day out, is typically referred to as the in-band management.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="remoteAccessMethodsTest"></a>
# ***
# ### ⚡ Test
# ***

# %% [markdown]
# &#x1F6A7;

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
